# %% [markdown]
# ### C0. Data distribution should be plotted on the spatial sampling

# %%
from os import listdir
from os.path import isfile, join
import numpy as np
import seaborn as sns

# EOLearn libraries:
from eolearn.core import EOTask, EOPatch, LinearWorkflow, LoadTask, SaveTask, FeatureType, EOExecutor
from eolearn.core import OverwritePermission

# Add to python path parent dictionary (to have acces to the data and util catalogue)
import sys
sys.path.append("../../")

# load site dependant constants (HERE YOU CAN CHOOSE DIFFERENT LOCATION)
from aoi_sites import upe_promice_area as site

# load utility functions
from utils import io_functions as io_utils
from utils import plot_functions as plot_utils

from scipy import ndimage

# %%
import numpy as np
rs = np.random.RandomState(10)
d = rs.normal(size=100)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Generate a random univariate dataset
d = rs.normal(size=100)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d
# Out:
# array([ 1.3315865 ,  0.71527897, -1.54540029, -0.00838385,  0.62133597,
#        -0.72008556,  0.26551159,  0.10854853,  0.00429143, -0.17460021,
#         0.43302619,  1.20303737, -0.96506567,  1.02827408,  0.22863013,
#         0.44513761, -1.13660221,  0.13513688,  1.484537  , -1.07980489,
#        -1.97772828, -1.7433723 ,  0.26607016,  2.38496733,  1.12369125,
#         1.67262221,  0.09914922,  1.39799638, -0.27124799,  0.61320418,
#        -0.26731719, -0.54930901,  0.1327083 , -0.47614201,  1.30847308,
#         0.19501328,  0.40020999, -0.33763234,  1.25647226, -0.7319695 ,
#         0.66023155, -0.35087189, -0.93943336, -0.48933722, -0.80459114,
#        -0.21269764, -0.33914025,  0.31216994,  0.56515267, -0.14742026,
#        -0.02590534,  0.2890942 , -0.53987907,  0.70816002,  0.84222474,
#         0.2035808 ,  2.39470366,  0.91745894, -0.11227247, -0.36218045,
#        -0.23218226, -0.5017289 ,  1.12878515, -0.69781003, -0.08112218,
# ...

# %%
from eolearn.core import EOTask, EOPatch

eo_patch = EOPatch.load('../../data/EOPatches/LANDSAT_8/UPE_PROMICE/UTM_22N/2014_05-2014_10/2974_maxcc_0.05_x-3_y-135')
eo_patch
# Out:
# EOPatch(
#   data: {
#     DATASET_CLD_200_dil_6_str2: numpy.ndarray(shape=(10, 333, 333, 11), dtype=float32)
#     LANDSAT_EUC_NORM_RAW_BANDS: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI_GREEN_NIR: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI_ICE: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI_NIR_SWIR_1: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI_NIR_SWIR_2: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
#     LANDSAT_QA_LAYERS: numpy.ndarray(shape=(10, 333, 333, 5), dtype=float32)
#     LANDSAT_RAW_BANDS: numpy.ndarray(shape=(10, 333, 333, 11), dtype=float32)
#     MODIS_EUC_NORM_RAW_BANDS: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
#     MODIS_NDWI: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
#     MODIS_NRB: numpy.ndarray(shape=(10, 333, 333, 1), dtype=float32)
# ...

# %%
data = eo_patch.data['LANDSAT_NDWI']

# %%
data.shape
# Out:
# (9, 333, 333, 1)

# %%
sami_flattened_data =  data.reshape(9,333*333)
flattened_data = data.reshape(9*333*333)

# %%
d = flattened_data

# %%
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[0]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[1]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[2]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[3]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[4]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[5]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[6]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[7]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d = sami_flattened_data[8]

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %% [markdown]
# ### Picture QA showcase

# %%
eo_patch = EOPatch.load('../../data/EOPatches/LANDSAT_8/UPE_PROMICE/UTM_22N/2019_05-2019_10/3473_maxcc_0.05_x-7_y-134')
eo_patch
# Out:
# EOPatch(
#   data: {
#     DATASET_CLD_200_dil_6_str2: numpy.ndarray(shape=(28, 333, 333, 11), dtype=float32)
#     LANDSAT_EUC_NORM_RAW_BANDS: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI_GREEN_NIR: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI_ICE: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI_NIR_SWIR_1: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
#     LANDSAT_NDWI_NIR_SWIR_2: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
#     LANDSAT_QA_LAYERS: numpy.ndarray(shape=(28, 333, 333, 5), dtype=float32)
#     LANDSAT_RAW_BANDS: numpy.ndarray(shape=(28, 333, 333, 11), dtype=float32)
#     MODIS_EUC_NORM_RAW_BANDS: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
#     MODIS_NDWI: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
#     MODIS_NRB: numpy.ndarray(shape=(28, 333, 333, 1), dtype=float32)
# ...

# %%
plot_utils.plot_RGB_LANDSAT_8_image(eo_patch, data_acces_name='LANDSAT_RAW_BANDS' ,datetime_idx=15 )
# Out:
# 2019-07-17 00:01:03
# Ploting...

# %%
plot_utils.plot_single_band_LANDSAT_8(eo_patch, data_acces_name = 'LANDSAT_NDWI', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_mask_LANDSAT_8(eo_patch, data_acces_name = 'WATER_MASK_ST_025', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_mask_LANDSAT_8(eo_patch, data_acces_name = 'WATER_MASK_ST_020', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_mask_LANDSAT_8(eo_patch, data_acces_name = 'WATER_MASK_ST_015', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_mask_LANDSAT_8(eo_patch, data_acces_name = 'WATER_MASK_ST_010', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_band_LANDSAT_8(eo_patch, data_acces_name = 'LANDSAT_NDWI_ICE', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_mask_LANDSAT_8(eo_patch, data_acces_name = 'WATER_MASK_ICE_ST_025', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_mask_LANDSAT_8(eo_patch, data_acces_name = 'WATER_MASK_ICE_ST_020', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_mask_LANDSAT_8(eo_patch, data_acces_name = 'WATER_MASK_ICE_ST_015', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_mask_LANDSAT_8(eo_patch, data_acces_name = 'WATER_MASK_ICE_ST_010', band_idx=0, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_single_band_LANDSAT_8(eo_patch, data_acces_name = 'LANDSAT_RAW_BANDS', band_idx=5, datetime_idx=15)
# Out:
# 2019-07-17 00:01:03

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch, 0, datetime_idx=0) # clouds
# Out:
# 2014-05-03 15:30:24

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch, 1, datetime_idx=1) # clouds and around
# Out:
# 2014-05-28 15:24:05

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch, 2,  datetime_idx=1) #cloudShadowConfidence
# Out:
# 2014-05-28 15:24:05

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch, 3,  datetime_idx=0) # cirrus
# Out:
# 2014-05-03 15:30:24

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch, 4, datetime_idx=0)  #snow ice
# Out:
# 2014-05-03 15:30:24

# %% [markdown]
# # Other picture without clouds

# %%
eo_patch_2 = EOPatch.load('../../data/EOPatches/LANDSAT_8/UPE_PROMICE/UTM_22N/2013_05-2013_10/2969_maxcc_0.05_x-3_y-130')

# %%
plot_utils.plot_RGB_LANDSAT_8_image(eo_patch_2, data_acces_name='LANDSAT_RAW_BANDS' ,datetime_idx=6 )
# Out:
# 2013-09-30 15:26:24
# Ploting...

# %%
plot_utils.plot_single_band_LANDSAT_8(eo_patch_2, data_acces_name = 'LANDSAT_RAW_BANDS', band_idx=5, datetime_idx=1)
# Out:
# 2013-08-20 15:32:44

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch_2, 0, datetime_idx=6) # clouds
# Out:
# 2013-09-30 15:26:24

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch_2, 1, datetime_idx=6) # clouds and aound
# Out:
# 2013-09-30 15:26:24

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch_2, 2,  datetime_idx=6) #cloudShadowConfidence
# Out:
# 2013-09-30 15:26:24

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch_2, 3,  datetime_idx=6) # cirrus
# Out:
# 2013-09-30 15:26:24

# %%
plot_utils.plot_qa_mask_LANDSAT_8(eo_patch_2, 4,  datetime_idx=6) # snow ice
# Out:
# 2013-09-30 15:26:24
